# %% [markdown]
# # RE2708 Group Project
# ## Topic: Exploring HDB Resale Flat Prices and HDB Median Rental Prices
#
# ##### Group 5 Members:
# **Goh Xi Rui (A0205650N)**
# **Jolene Tan Wei (A0205590J)**
# **Tan Chern Yin (A0290243L)**
# **Ow Zhi Sheng (A0200452Y)**
# **Wong Liyang (A0183851Y)**
#
# In Singapore, prices for HDB flats ranges from 200,000 SGD to even up to 1,000,000 SGD. As such, the issue of purchasing a HDB flat in Singapore or renting a flat is a widely discussed topic. Hence, our group is keen to explore HDB resale flat prices as well as HDB flat median rents in the 5 planning area and regions of Singapore through the use of data analytics.
#
# This project aims to provide an overall view of the HDB resale flat market and HDB flat rental market for potential homebuyers or renters, and to help them make an informed decision powered by Python.

# %% [markdown]
# ## Deliverable A: Reading input data from at least 2 publicly available online sources

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as smf
import geopandas
import requests
# %matplotlib inline

# %%
d1 = pd.read_csv('median-rent-by-town-and-flat-type.csv')

# %%
d2 = pd.read_csv('Monthly Resale Prices.csv')

# %% [markdown]
# ## Deliverable B: Running 5 operations with text variables

# %% [markdown]
# Hello! Are you looking to purchase a HDB resale flat or to rent? Let us help you in your journey to your new home!
#
# ### Help Box 1
#
# To key in your selection, please enter 1 if you want to rent a flat or enter 2 if you want to purchase a resale flat.
#
# Please key in your selection as such (E.g. A = 1 or A = 2)

# %%
A = 1

if A > 1:
    print("Great Choice! Let's find a suitable resale HDB that fits your criterias together. Please proceed to Help Box 2.")
else:
    print("Great Choice! Let's find a suitable HDB rental for you today. Please proceed to Help Box 3. ")
# Out:
# Great Choice! Let's find a suitable HDB rental for you today. Please proceed to Help Box 3.

# %% [markdown]
# ### Help Box 2
#
# Now, what is the resale price that you are looking for? Let us tell you if it's above or below market value.
#
# Please enter your desired budget as such (r = 200000)

# %%
r = 435000

if r>320000:
    print("The resale price of $" + str(r) + " is above the market value!")
else:
    print("The resale price of $" + str(r) + " is below the market value...")
# Out:
# The resale price of $435000 is above the market value!

# %% [markdown]
# ### Help Box 3
#
# Now, what is your desired budget for HDB rental? Let us recommend areas that fits your budget!
#
# Please enter your desired budget as such ( r = 2000)

# %%
R = 1800

if R>2000:
    print("We got you covered! Consider areas in the Central such as Bukit Merah & Queenstown.")
else: 
    print("We got you covered! Consider areas in the North such as Yishun and Woodlands.")
# Out:
# We got you covered! Consider areas in the North such as Yishun and Woodlands.

# %% [markdown]
# ### Help Box 4
#
# Hey there! If you are not sure what regions your favourite town is in, just enter it within the square brackets below [" "].
#
# For Example: print(planningregions["Toa Payoh"]
#
# Our most searched towns are Bishan, Sembawang, Ang Mo kio, Bukit Batok, Bedok, Toa Payoh and Yishun.

# %%
planningregions = {
    "Bishan": "Central",
    "Sembawang": "North",
    "Ang mo kio": "North East",
    "Bukit Batok": "West",
    "Bedok": "East",
    "Toa Payoh": "Central",
    "Yishun": "North"
}
print(planningregions["Yishun"])
# Out:
# North

# %% [markdown]
# ### Help Box 5
#
# Hey there! If you are not sure what towns are in your favourite region, just enter it within the square brackets below [" "].
#
# For Example: in mylist["West"]
#
# Let us show you the results of the top 3 towns in those areas!

# %%
mylist = {
    "CENTRAL": ["BISHAN","QUEENSTOWN","TOA PAYOH"],
    "NORTH": ["SEMBAWANG", "WOODLANDS", "YISHUN"],
    "EAST": ["BEDOK","PASIR RIS", "TAMPINES"],
    "WEST": ["BUKIT BATOK","CLEMENTI", "JURONG EAST"],
    "NORTH EAST": ["ANG MO KIO", "HOUGANG", "SERANGOON"]
    
}

for x in mylist["CENTRAL"]:
    print(x)
# Out:
# BISHAN
# QUEENSTOWN
# TOA PAYOH

# %% [markdown]
# ### From the above, we have coded 5 operations using text variables as illustrated from Help Box 1 to 5.
# **If-else conditions**
# 1. To decide whether the resale price is above/below market value, we can use if-else conditions to set certain price criteria.
# 2. Home buyers/tenants can input a number based on the service they wish to use.
#
# **Dictionaries**
# 3. Tenants can input their budget for renting a HDB flat and obtain a list of suggested towns based on their budget.
# 4. To find out which region a certain town lies in, we can use dictionaries.
# 5. To generate which towns exist under a certain region by looping through a dictionary.

# %% [markdown]
# ## Deliverable C: Running 5 operations with numerical variables using the package `numpy`

# %% [markdown]
# I am intending to buy a 3 room AMK flat in Jan 2020 which costs $268000 and I want to get a house loan.
# So, I am trying to compare which type of SIBOR should I get, 1 month or 3 months.
#
# The complete home loan rate is then calculated by adding the bank’s charges (the fixed spread) to the SIBOR rate.
# Hence, assuming that the fixed spread is 0.70%.
# The below is the total interest that determines the monthly payments.
#
# The 1 Month SIBOR rate is 1.749%.
# The loaning bank has a fixed spread of 0.70%.
# The total interest for the month: 1.749% (1 Month SIBOR) + 0.70% (fixed spread) = 2.449%

# %%
price = 268000
interest_rate1 = 0.02449
years = 30
payments_year = 12

pmt1 = -1*np.pmt(0.02449/12, 30*12, 268000)
print(pmt1)
# Out:
# 1051.8314402234553
# <ipython-input-9-489f69fd9e28>:6: DeprecationWarning: numpy.pmt is deprecated and will be removed from NumPy 1.20. Use numpy_financial.pmt instead (https://pypi.org/project/numpy-financial/).
#   pmt1 = -1*np.pmt(0.02449/12, 30*12, 268000)

# %%
mortgage1 = np.arange(0,3,dtype=np)
mortgage1[0] = price 
mortgage1[1] = interest_rate1
mortgage1[2] = np.round(pmt1, decimals = 2)

print(mortgage1)
# Out:
# [268000 0.02449 1051.83]

# %% [markdown]
# The 3 Month SIBOR rate is 1.774%.
# The loaning bank has a fixed spread of 0.70%.
# The total interest for the month: 1.774% (3 Month SIBOR) + 0.70% (fixed spread) = 2.474%

# %%
price = 268000
interest_rate2 = 0.02474
years = 30
payments_year = 12

pmt2 = -1*np.pmt(0.02474/12, 30*12, 268000)
print(pmt2)
# Out:
# 1055.3047641943876
# <ipython-input-11-4e361f16582c>:6: DeprecationWarning: numpy.pmt is deprecated and will be removed from NumPy 1.20. Use numpy_financial.pmt instead (https://pypi.org/project/numpy-financial/).
#   pmt2 = -1*np.pmt(0.02474/12, 30*12, 268000)

# %%
mortgage2 = np.arange(0,3,dtype=np)
mortgage2[0] = price 
mortgage2[1] = interest_rate2
mortgage2[2] = np.round(pmt2, decimals = 2)

print(mortgage2)
# Out:
# [268000 0.02474 1055.3]

# %%
difference = np.subtract((pmt2),(pmt1))

np.round(difference, decimals = 2)
# Out:
# 3.47

# %% [markdown]
# Difference in Monthly Payment: $3.47

# %% [markdown]
# In this example, because the house loan is only $268000, hence the difference in monthly payment is rather small. If the house loan amoount is larger, there will be a larger difference.
#
# Hence, as shown, the 3 month SIBOR has a higher monthly payment than the 1 month SIBOR but one has to take note of the current direction of interest rates. When SIBOR rates are falling, a 1 month rate will be cheaper than a 3 month rate. However, if interest rates are rising, the opposite is true.
#
# 1 month SIBOR rates adjust very quickly, whereas a 3 month rate takes time to adjust. So if SIBOR is falling month-on-month, the 1 month SIBOR would match the plunge, causing one's home loan to cost less.
#
# But if SIBOR is rising, the 1 month rate would match it and rise just as quickly. Conversely, a 3 month SIBOR would maintain the lower rates from previous months.

# %% [markdown]
# ## Deliverable D: Writing 1 `loc` function to clean the data

# %% [markdown]
# Before moving to our other steps, we have to clean the datasets from missing or 0 values.

# %%
d1['median_rent'] = pd.to_numeric(d1['median_rent'], errors = 'coerce')
d1 = d1.dropna()
d1 = d1.loc[d1['median_rent']>0]

# %%
d2['resale_price'] = pd.to_numeric(d2['resale_price'], errors = 'coerce')
d2 = d2.dropna()
d2 = d2.loc[d2['resale_price']>0]

# %% [markdown]
# **Explaination of codes:**
# - dropna() : To drop missing observations "-" as illustrated in d1.
# - pd.to_numeric : Converting all the "na" in the table in d1 into missing variables, 'NaN'.
# - d1['median_rent']>0 / d2.loc[d2['resale_price']>0] : To eliminate any 0 data in the table so that we only take the positive values

# %% [markdown]
# ## Deliverable E: Building 5 tables of summary statistics, groups or pivot tables using the package

# %%
d1.describe().round(2).T
# Out:
#               count     mean     std     min     25%     50%     75%     max
# median_rent  1241.0  2058.85  322.23  1380.0  1800.0  2000.0  2300.0  2950.0

# %% [markdown]
# The table above provides for the summary statistics for the key variables in the data on Average Median HDB Rental Prices.

# %%
d2.describe().round(2).T
# Out:
#                        count       mean        std       min       25%  \
# floor_area_sqm       80337.0      97.59      24.25      31.0      82.0
# lease_commence_date  80337.0    1994.12      12.84    1966.0    1984.0
# resale_price         80337.0  439150.26  153220.57  140000.0  330000.0
#
#                           50%       75%        max
# floor_area_sqm           95.0     112.0      249.0
# lease_commence_date    1994.0    2003.0     2019.0
# resale_price         410000.0  515000.0  1258000.0

# %% [markdown]
# The table above provides summary statistics for the key variables in the data on Monthly HDB Resale Prices.

# %% [markdown]
# **Filtering Dataset 1**

# %%
np.round(d1.describe(), 2).T[['mean', 'std', '25%', '50%', '75%']]
# Out:
#                 mean     std     25%     50%     75%
# median_rent  2058.85  322.23  1800.0  2000.0  2300.0

# %% [markdown]
# This allows us to focus on data that we are interested in, while filtering unwanted data such as count and max.
# For this scenario, we are able to obtain the mean, standard deviation, 25th percentile, 50th percentile and 75 percentile of median rent prices.

# %% [markdown]
# **Filtering Dataset 2**

# %%
print(d1['town'].unique())
# Out:
# ['ANG MO KIO' 'BEDOK' 'BISHAN' 'BUKIT BATOK' 'BUKIT MERAH' 'BUKIT PANJANG'
#  'CENTRAL' 'CHOA CHU KANG' 'CLEMENTI' 'GEYLANG' 'HOUGANG' 'JURONG EAST'
#  'JURONG WEST' 'KALLANG/WHAMPOA' 'MARINE PARADE' 'PASIR RIS' 'PUNGGOL'
#  'QUEENSTOWN' 'SEMBAWANG' 'SENGKANG' 'SERANGOON' 'TAMPINES' 'TOA PAYOH'
#  'WOODLANDS' 'YISHUN']

# %% [markdown]
# This allows us to focus on data that we are interested in, by producing unique data instead of repeated data. For this scenario, we are able to obtain all the towns recorded within Data Source d1.

# %% [markdown]
# **Pivot table 1: Resale prices of the different flat types in the 26 towns in SG (Towns sorted in alphabetical order)**

# %%
pd.pivot_table(d2, values='resale_price', index=['town'], columns=['flat_type']).round()
# Out:
# flat_type          1 ROOM    2 ROOM    3 ROOM    4 ROOM    5 ROOM  EXECUTIVE
# town
# ANG MO KIO            NaN  213576.0  296207.0  471828.0  679799.0   812604.0
# BEDOK                 NaN  217715.0  292845.0  434030.0  576338.0   715585.0
# BISHAN                NaN       NaN  358142.0  559221.0  770250.0   895079.0
# BUKIT BATOK           NaN       NaN  263204.0  377238.0  520321.0   616583.0
# BUKIT MERAH      183899.0  243831.0  380927.0  651434.0  768609.0        NaN
# BUKIT PANJANG         NaN  231516.0  295081.0  391301.0  486878.0   592599.0
# BUKIT TIMAH           NaN       NaN  416592.0  634686.0  820313.0   952964.0
# CENTRAL AREA          NaN  237455.0  411189.0  741509.0  951036.0        NaN
# CHOA CHU KANG         NaN  226786.0  282121.0  347567.0  416850.0   530970.0
# CLEMENTI              NaN  300050.0  329570.0  559992.0  717220.0   819806.0
# GEYLANG               NaN  201180.0  282681.0  516495.0  680434.0   738266.0
# ...

# %% [markdown]
# **Pivot table 2: Resale prices sorted in increasing order (Lowest to highest price)**

# %%
d2.groupby('town').mean().sort_values(by='resale_price')
# Out:
#                  floor_area_sqm  lease_commence_date   resale_price
# town
# YISHUN                92.611566          1994.212633  362110.313523
# WOODLANDS            106.406546          1997.042200  378922.761402
# BUKIT BATOK           95.512360          1988.991195  380315.709702
# SEMBAWANG            103.688213          2003.076046  380898.284163
# CHOA CHU KANG        110.596760          1997.312631  388410.044704
# JURONG WEST          102.482453          1994.810829  390695.527346
# ANG MO KIO            84.961251          1984.370606  408721.693330
# BEDOK                 89.322773          1983.970845  409326.421717
# JURONG EAST           97.347462          1989.320134  412863.142220
# BUKIT PANJANG        102.583359          2000.784485  427985.359399
# GEYLANG               83.262656          1982.947614  428054.042531
# HOUGANG              101.767931          1992.773909  433257.014522
# SENGKANG              99.517322          2007.219257  437493.724195
# ...

# %% [markdown]
# ## Deliverable F: Plotting 5 figures using the package `matplotlib`

# %% [markdown]
# We will be using data from both **Data Source 1, d1** and **Data Source 2, d2**
#
# Because there are too many towns, illustrating each of these towns in figures would not be effective. Hence, we will merge the data of d1 and d2 with 'towns by regions.csv'. In this way, we can label each town as belonging to a certain region of Singapore.

# %%
dreg = pd.read_csv('town regions.csv')
dreg
# Out:
#                town      region
# 0            BISHAN     CENTRAL
# 1       BUKIT MERAH     CENTRAL
# 2       BUKIT TIMAH     CENTRAL
# 3      CENTRAL AREA     CENTRAL
# 4           GEYLANG     CENTRAL
# 5   KALLANG/WHAMPOA     CENTRAL
# 6     MARINE PARADE     CENTRAL
# 7        QUEENSTOWN     CENTRAL
# 8         TOA PAYOH     CENTRAL
# 9         SEMBAWANG       NORTH
# 10        WOODLANDS       NORTH
# 11           YISHUN       NORTH
# 12       ANG MO KIO  NORTH EAST
# 13          HOUGANG  NORTH EAST
# 14          PUNGGOL  NORTH EAST
# 15         SENGKANG  NORTH EAST
# 16        SERANGOON  NORTH EAST
# 17      BUKIT BATOK        WEST
# 18    BUKIT PANJANG        WEST
# 19    CHOA CHU KANG        WEST
# 20         CLEMENTI        WEST
# 21      JURONG EAST        WEST
# 22      JURONG WEST        WEST
# 23            BEDOK        EAST
# 24        PASIR RIS        EAST
# 25         TAMPINES        EAST

# %%
d1merged = pd.merge(d1, dreg, on='town')
d1merged
# Out:
#       quarter        town flat_type  median_rent      region
# 0     2017-Q1  ANG MO KIO      3-RM       1750.0  NORTH EAST
# 1     2017-Q1  ANG MO KIO      4-RM       2200.0  NORTH EAST
# 2     2017-Q1  ANG MO KIO      5-RM       2400.0  NORTH EAST
# 3     2017-Q2  ANG MO KIO      3-RM       1750.0  NORTH EAST
# 4     2017-Q2  ANG MO KIO      4-RM       2250.0  NORTH EAST
# ...       ...         ...       ...          ...         ...
# 1206  2020-Q2      YISHUN      5-RM       2000.0       NORTH
# 1207  2020-Q2      YISHUN      EXEC       2100.0       NORTH
# 1208  2020-Q3      YISHUN      3-RM       1650.0       NORTH
# 1209  2020-Q3      YISHUN      4-RM       1800.0       NORTH
# 1210  2020-Q3      YISHUN      5-RM       2000.0       NORTH
#
# [1211 rows x 5 columns]

# %%
d2merged = pd.merge(d2, dreg, on='town')
d2merged
# Out:
#          month        town  flat_type block        street_name storey_range  \
# 0      2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1      2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2      2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3      2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4      2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...        ...         ...        ...   ...                ...          ...
# 80332  2020-09      YISHUN     5 ROOM   716       YISHUN ST 71     07 TO 09
# 80333  2020-09      YISHUN     5 ROOM   760       YISHUN ST 72     07 TO 09
# 80334  2020-09      YISHUN     5 ROOM   835       YISHUN ST 81     04 TO 06
# 80335  2020-09      YISHUN  EXECUTIVE   791       YISHUN AVE 2     04 TO 06
# 80336  2020-09      YISHUN  EXECUTIVE   387     YISHUN RING RD     04 TO 06
#
# ...

# %% [markdown]
# **Figure 1: Frequency of HDB Resale Transactions by Regions**

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))
dg = d2merged.groupby('region').count()

plt.pie(dg['resale_price'],autopct='%.1f',labels=dg.index)

plt.title('Figure 1:\n Frequency of HDB Resale Transactions by Regions (%)')
plt.grid(color=(.9,.9,.9))

# %% [markdown]
# **Interpretation:**
#
# The frequency of transactions is the highest in the North East 25.6%, and the lowest in the East, of 14.9%.

# %% [markdown]
# **Figure 2: Frequency of Rented HDB Transactions by Regions (%)**

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))
dg = d1merged.groupby('region').count()

plt.pie(dg['median_rent'],autopct='%.1f',labels=dg.index)

plt.title('Figure 2:\n Frequency of Rented HDB Transactions by Regions (%)')
plt.grid(color=(.9,.9,.9))

# %% [markdown]
# **Interpretation:**
#
# The highest frequency of transactions is of the same percentage in both the West and in the Central area of 25.6%. The lowest frequency of rental transaction lies in the East, of 13.2%.
#
# This result is starkly different from the frequency of HDB resale transactions in Figure 1.
#
# _**So, what can we tell from these data?**_
#
# What we can infer from this data is that perhaps people are more inclined to rent their flats in the Central or Western area. Perhaps due to its close proximity to where they work. However, when it comes to purchasing a flat, or more specifically a resale flat, more people would prefer to purchase it in other planning regions apart from the Central or the West.
#
# We will now evaluate the possible reasons for this trend by dwelving deeper into comparing the resale prices/rental prices with the region of their HDB flats and their flat types. This way, we can also see if renting a house is indeed more attractive than having to purchase a resale house in these planning regions.

# %% [markdown]
# **Figure 3: Average HDB Resale Prices by Regions**

# %%
fig, ax = plt.subplots(1,1, figsize=(10,6))
dg = d2merged.groupby('region').mean()

plt.bar(dg.index,dg['resale_price'],width=.5,linewidth=2, color=(.6, .2, .3))

plt.title('Figure 3:\n Average HDB Resale Prices by Regions (S$)')
plt.xlabel('Planning Regions in Singapore')
plt.ylabel('Average Resale Transaction Price (S$)')
plt.grid(color=(.9,.9,.9))

# %% [markdown]
# **Interpretation:**
#
# The average highest HDB resale prices is in the Central, and the lowest in the North.

# %% [markdown]
# **Figure 4: Average Median HDB Rent Prices by Regions**

# %%
fig, ax = plt.subplots(1,1, figsize=(10,6))
dg = d1merged.groupby('region').mean()

plt.bar(dg.index,dg['median_rent'],width=.5,linewidth=2)

plt.title('Figure 4:\n Average Median HDB Rent Prices by Regions (S$)')
plt.xlabel('Planning Regions in Singapore')
plt.ylabel('Median Rent (S$)')
plt.grid(color=(.9,.9,.9))

# %% [markdown]
# **Interpretation:**
#
# The average highest median HDB prices is in the Central, and the lowest in the North. This result is similar to that from Figure 3.
#
# This result is also expected, that HDB prices would normally be higher in the Central due to its ease of access to workplace and to town.
#
# However the only slight difference between Figure 3 and 4 is that the range of resale prices fluctuate about a larger range as compared to that of in median rent prices. This means like unlike HDB resale transaction prices, the difference in rental prices around Singapore has a smaller range!
#
# _**So, what can we tell from this data?**_
#
# For example, if you are finding for a place to stay in Singapore, rented housing might seem as a more attractive choice, because you will now be able to choose for a place that you really want to stay in, without having to consider much about the differences in prices between the different regions due to the relatively smaller range in differences.

# %% [markdown]
# **Figure 5: Relationship between Flat Types and Average HDB Resale Prices**

# %%
fig, ax = plt.subplots(1,1, figsize=(10,6))
dg = d2merged.groupby('flat_type').count()

plt.bar(dg.index,dg['resale_price'],width=.5,linewidth=2, color=(.6, .2, .3))

plt.title('Figure 5:\n Relationship between Flat Types and Average HDB Resale Prices')
plt.xlabel('Flat Types')
plt.ylabel('Average Resale Transaction Price (S$)')
plt.grid(color=(.9,.9,.9))

# %% [markdown]
# **Interpretation:**
#
#  4-room HDB flat type corresponds with the highest average resale flat prices, while 1-room HDB flat type corresponds with the lowest average resale flat prices. Apart from this, the average transaction prices of the different flat types covers a large range.

# %% [markdown]
# **Figure 6: Relationship between Flat Types and Average Median Rent Prices of HDB Flats (by regions)**

# %%
fig, ax = plt.subplots(1,1, figsize=(10,6))
dg = d1merged.groupby('flat_type').count()

plt.bar(dg.index,dg['median_rent'],width=.5,linewidth=2)

plt.title('Figure 6:\n Relationship between Flat Types and Average Median Rent Prices of HDB Flats')
plt.xlabel('Flat Types')
plt.ylabel('Median Rent (S$)')
plt.grid(color=(.9,.9,.9))

# %% [markdown]
# **Interpretation:**
#
# 4-room HDB flat type corresponds with the highest average resale flat prices, while 2-room HDB flat type corresponds with the lowest average resale flat prices. This result is somewhat similar to that from Figure 5.
#
# Firstly, there is no data regarding median rental prices for 1-room flat types. And some differences to note is that the range of prices between the different flat types is smaller for median rent prices, as compared average resale prices.
#
# _**So, what can we tell from this data?**_
#
# Firstly, to address the missing data for median rental prices for 1-room flat types. This is due to the limitation from our data source, as these median rental prices are not available.
#
# Now take for the example that you want to compare the prices between the different flat types. For average HDB resale prices, it has a greater range as compared to that of the median rental prices. This implies that similarly, rented housing might seem as a more attractive choice, because it might be more worth to rent for a bigger place to stay in, as compared to purchasing a smaller house to stay in, since prices of the different flat types differ by a smaller range.

# %% [markdown]
# ## Deliverable G: Estimating 3 regression models using the package `statsmodels`

# %% [markdown]
# **Regression 1: Identifying the effect of floor area on the average price of resale HDB flats**

# %%
d2reg1a = smf.ols("resale_price ~ floor_area_sqm", data = d2).fit()
print(d2reg1a.params)
# Out:
# Intercept         49963.331048
# floor_area_sqm     3988.092224
# dtype: float64

# %% [markdown]
# We can interpret the following from the results:
#
# _**For any additional square meter, the average price of resale HDB flats is increasing by $3988**_

# %%
d2reg1b = smf.ols("np.log(resale_price) ~ np.log(floor_area_sqm)", data = d2).fit()
print(d2reg1b.params)
# Out:
# Intercept                 8.894066
# np.log(floor_area_sqm)    0.888903
# dtype: float64

# %% [markdown]
# We can interpret the following from the results:
#
# _**For any additional 1% larger floor area, the average price of resale HDB flats is increasing by 0.89%**_

# %%
alpha = 49963.331048
beta = 3988.092224

d2['FitPrice'] = alpha + beta*d2['floor_area_sqm']

fig, ax = plt.subplots(1,1)
plt.scatter(d2['floor_area_sqm'],d2['resale_price'],s=4)
plt.plot(d2['floor_area_sqm'],d2['FitPrice'],color=(0,0,0))
plt.title('Price increase for 1 additional $m^2$')
plt.xlabel('Floor area ($m^2$)')
plt.ylabel('Transaction price (S$ 1 millions)')
plt.legend(['Linear fit','Actual transactions'])
plt.grid(color=(.9,.9,.9))
plt.show()

# %%
d2reg1b.conf_int()
# Out:
#                                0         1
# Intercept               8.865498  8.922633
# np.log(floor_area_sqm)  0.882633  0.895174

# %% [markdown]
# We can interpret the following from the results:
# #### 95% Confidence Interval
# _**With a 95% probability, the effect of the floor area on the average price of resale HDBs is between 0.88% and 0.90%**_

# %% [markdown]
# ## Deliverable H: Obtaining and using 2 data series through web scraping

# %% [markdown]
# Will the size of parks have any effect on the resale prices of HDB?

# %%
m = requests.get('https://en.wikipedia.org/wiki/List_of_parks_in_Singapore')

# %%
df3 = pd.read_html(m.text)

# %%
df3 = df3[0]
df3 = df3.drop(columns=df3.columns[[1]])
df3
# Out:
#                            Name  Area (m)
# 0                Admiralty Park  270000.0
# 1   Ang Mo Kio Town Garden East   49000.0
# 2   Ang Mo Kio Town Garden West  206000.0
# 3               Bedok Town Park  146000.0
# 4        Bishan-Ang Mo Kio Park  620000.0
# ..                          ...       ...
# 70    Yishun Neighbourhood Park   77000.0
# 71                  Yishun Park  139000.0
# 72             Yishun Pond Park   23000.0
# 73           Youth Olympic Park    4000.0
# 74                Zhenghua Park  135000.0
#
# [75 rows x 2 columns]

# %%
df3.groupby('Name').max().sort_values(by='Area (m)').tail(5)
# Out:
#                                   Area (m)
# Name
# Central Catchment Nature Reserve       NaN
# Ketam Mountain Bike Park               NaN
# Labrador Park                          NaN
# Sengkang Sculpture Park                NaN
# Waterboat House Garden                 NaN

# %% [markdown]
# We can conclude that the size of the park actually do not have much effect on the resale price of HDB. The parks with the highest area is not near HDB with the highest resale price.

# %%
m = requests.get('https://en.wikipedia.org/wiki/Singapore_Police_Force')

# %%
df3 = pd.read_html(m.text)

# %%
df3 = df3[7]
df3 = df3.drop(columns=df3.columns[[1]])
df3
# Out:
#                                          Units  \
# 0                   Ang Mo Kio Police Division
# 1                        Bedok Police Division
# 2                      Central Police Division
# 3                     Clementi Police Division
# 4                       Jurong Police Division
# 5                      Tanglin Police Division
# 6                    Woodlands Police Division
# 7                      Airport Police Division
# 8                            Gurkha Contingent
# 9   Home Team School of Criminal Investigation
# 10                          Police Coast Guard
# 11            Police Operations Command Centre
# 12           Public Transport Security Command
# 13                 Protective Security Command
# 14                     Police Security Command
# 15                  Special Operations Command
# 16                              Traffic Police
# 17                            Training Command
#
#                                Area of responsibility   Ref
# ...

# %% [markdown]
# Likewise,the proximity of police stations have no relationship with HDB resale price.

# %% [markdown]
# ## Deliverable I: Plotting 2 location maps using the package `geopandas`

# %% [markdown]
# Finally moving on to the visuals! In this section, we will be able to visualise where exactly in Singapore that has the highest HDB rental or resale prices.

# %%
gf0 = geopandas.read_file('zip://master-plan-2014-planning-area-boundary-no-sea-shp.zip')
gf0
# Out:
#     OBJECTID               PLN_AREA_N PLN_AREA_C CA_IND           REGION_N  \
# 0          1               ANG MO KIO         AM      N  NORTH-EAST REGION
# 1          2                    BEDOK         BD      N        EAST REGION
# 2          3                   BISHAN         BS      N     CENTRAL REGION
# 3          4                 BOON LAY         BL      N        WEST REGION
# 4          5              BUKIT BATOK         BK      N        WEST REGION
# 5          6              BUKIT MERAH         BM      N     CENTRAL REGION
# 6          7            BUKIT PANJANG         BP      N        WEST REGION
# 7          8              BUKIT TIMAH         BT      N     CENTRAL REGION
# 8          9                  GEYLANG         GL      N     CENTRAL REGION
# 9         10                  KALLANG         KL      N     CENTRAL REGION
# 10        11                   NOVENA         NV      N     CENTRAL REGION
# ...

# %%
fig, axis = plt.subplots(1,1,figsize=(20,10))
gf0.plot(ax=axis,color=(.7,.7,.7))
gf0.loc[gf0['PLN_AREA_N']=='BISHAN'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='BUKIT MERAH'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='BUKIT TIMAH'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='DOWNTOWN CORE'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='GEYLANG'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='KALLANG'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='MARINE PARADE'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='QUEENSTOWN'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='TOA PAYOH'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='SEMBAWANG'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='WOODLANDS'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='YISHUN'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='ANG MO KIO'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='HOUGANG'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='PUNGGOL'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='SENG KANG'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='SERANGOON'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='BUKIT PANJANG'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='CHOA CHU KANG'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='CLEMENTI'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='JURONG EAST'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='JURONG WEST'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='BEDOK'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='PASIR RIS'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='TAMPINES'].plot(ax=axis,color=(1,0,0))
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.title('HDB areas we are covering',fontsize=30)

plt.show()
# Out:
# C:\Users\wongl\anaconda3\lib\site-packages\geopandas\plotting.py:604: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(

# %%
fig, axis = plt.subplots(1,1,figsize=(20,10))
gf0.plot(ax=axis,color=(.7,.7,.7))
gf0.loc[gf0['PLN_AREA_N']=='QUEENSTOWN'].plot(ax=axis,color=(1,0,0))
gf0.loc[gf0['PLN_AREA_N']=='BISHAN'].plot(ax=axis,color=(.8,0,.0))
gf0.loc[gf0['PLN_AREA_N']=='BUKIT MERAH'].plot(ax=axis,color=(.6,0,0))
gf0.loc[gf0['PLN_AREA_N']=='KALLANG'].plot(ax=axis,color=(.4,0,.0))
gf0.loc[gf0['PLN_AREA_N']=='DOWNTOWN CORE'].plot(ax=axis, color= (.4,.4,0))
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.title('Top 5 town with highest HDB resale price!',fontsize=30)

gf1 = gf0.loc[gf0['PLN_AREA_N']=='QUEENSTOWN']
gf2 = gf0.loc[gf0['PLN_AREA_N']=='BISHAN']
gf3 = gf0.loc[gf0['PLN_AREA_N']=='BUKIT MERAH']
gf4 = gf0.loc[gf0['PLN_AREA_N']=='KALLANG']
gf5 = gf0.loc[gf0['PLN_AREA_N']=='DOWNTOWN CORE']

for i in gf1.index:
    plt.text(gf1['X_ADDR'][i],gf1['Y_ADDR'][i],gf1['PLN_AREA_N'][i],fontsize=13,fontweight='bold')
for i in gf2.index:
    plt.text(gf2['X_ADDR'][i],gf2['Y_ADDR'][i],gf2['PLN_AREA_N'][i],fontsize=13,fontweight='bold')
for i in gf3.index:   
    plt.text(gf3['X_ADDR'][i],gf3['Y_ADDR'][i],gf3['PLN_AREA_N'][i],fontsize=13,fontweight='bold')
for i in gf4.index:
    plt.text(gf4['X_ADDR'][i],gf4['Y_ADDR'][i],gf4['PLN_AREA_N'][i],fontsize=13,fontweight='bold')
for i in gf5.index:
    plt.text(gf5['X_ADDR'][i],gf5['Y_ADDR'][i],gf5['PLN_AREA_N'][i],fontsize=13,fontweight='bold')


plt.show()

# %%
fig, axis = plt.subplots(1,1,figsize=(20,10))
gf0.plot(ax=axis,color=(.7,.7,.7))
gf0.loc[gf0['PLN_AREA_N']=='CLEMENTI'].plot(ax=axis,color=(0,1,0))
gf0.loc[gf0['PLN_AREA_N']=='KALLANG'].plot(ax=axis,color=(0,.8,0))
gf0.loc[gf0['PLN_AREA_N']=='DOWNTOWN CORE'].plot(ax=axis,color=(0,.6,0))
gf0.loc[gf0['PLN_AREA_N']=='BUKIT MERAH'].plot(ax=axis,color=(0,.4,0))
gf0.loc[gf0['PLN_AREA_N']=='QUEENSTOWN'].plot(ax=axis, color= (0,.4,.4))
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.title('Top 5 town with highest HDB rental price!',fontsize=30)

gf1 = gf0.loc[gf0['PLN_AREA_N']=='CLEMENTI']
gf2 = gf0.loc[gf0['PLN_AREA_N']=='KALLANG']
gf3 = gf0.loc[gf0['PLN_AREA_N']=='DOWNTOWN CORE']
gf4 = gf0.loc[gf0['PLN_AREA_N']=='BUKIT MERAH']
gf5 = gf0.loc[gf0['PLN_AREA_N']=='QUEENSTOWN']

for i in gf1.index:
    plt.text(gf1['X_ADDR'][i],gf1['Y_ADDR'][i],gf1['PLN_AREA_N'][i],fontsize=13,fontweight='bold')
for i in gf2.index:
    plt.text(gf2['X_ADDR'][i],gf2['Y_ADDR'][i],gf2['PLN_AREA_N'][i],fontsize=13,fontweight='bold')
for i in gf3.index:
    plt.text(gf3['X_ADDR'][i],gf3['Y_ADDR'][i],gf3['PLN_AREA_N'][i],fontsize=13,fontweight='bold')
for i in gf4.index:
    plt.text(gf4['X_ADDR'][i],gf4['Y_ADDR'][i],gf4['PLN_AREA_N'][i],fontsize=13,fontweight='bold')
for i in gf5.index:
    plt.text(gf5['X_ADDR'][i],gf5['Y_ADDR'][i],gf5['PLN_AREA_N'][i],fontsize=13,fontweight='bold')

plt.show()

# %% [markdown]
# **Interpretation:**
#
# From the 2 maps, we can see that the rental prices of HDB is actually quite related to the resale prices of HDB. Except for an anomaly in Bishan. Towns that have a high HDB resale price will also have high rental prices. Moreover, we can also identify that these areas that corresponds to the highest HDB resale/rental prices are located near the Central/in the Central area itself. This means that people are often more inclined to purchase a property that is nearer to their jobs.
